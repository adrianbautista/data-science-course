# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
# makes sure the plots happen inside the iPython notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Acquisition

# %%
df = pd.read_table('./imdb_top_10000.txt', header=None)

# %% [markdown]
# # Cleaning

# %%
column_names = ['ID1', 'title', 'year', 'rating', 'ID2', 'duration', 'genres']
df.columns = column_names
df.head()
# Out:
#          ID1                            title  year  rating     ID2  \
# 0  tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479
# 1  tt0110912              Pulp Fiction (1994)  1994     9.0  490065
# 2  tt0137523                Fight Club (1999)  1999     8.8  458173
# 3  tt0133093                The Matrix (1999)  1999     8.7  448114
# 4  tt1375666                 Inception (2010)  2010     8.9  385149
#
#     duration                            genres
# 0  142 mins.                       Crime|Drama
# 1  154 mins.                    Crime|Thriller
# 2  139 mins.            Drama|Mystery|Thriller
# 3  136 mins.           Action|Adventure|Sci-Fi
# 4  148 mins.  Action|Adventure|Sci-Fi|Thriller

# %%
# data.duraction.apply(lambda y: y.split('(')[0]))

df['duration'] = df['duration'].str.replace(' mins.', '')
df.head()
# Out:
#          ID1                            title  year  rating     ID2 duration  \
# 0  tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479      142
# 1  tt0110912              Pulp Fiction (1994)  1994     9.0  490065      154
# 2  tt0137523                Fight Club (1999)  1999     8.8  458173      139
# 3  tt0133093                The Matrix (1999)  1999     8.7  448114      136
# 4  tt1375666                 Inception (2010)  2010     8.9  385149      148
#
#                              genres
# 0                       Crime|Drama
# 1                    Crime|Thriller
# 2            Drama|Mystery|Thriller
# 3           Action|Adventure|Sci-Fi
# 4  Action|Adventure|Sci-Fi|Thriller

# %%
df['title'] = df['title'].str.replace('\s\(\d+\)', '')
df.head()
# Out:
#          ID1                     title  year  rating     ID2 duration  \
# 0  tt0111161  The Shawshank Redemption  1994     9.2  619479      142
# 1  tt0110912              Pulp Fiction  1994     9.0  490065      154
# 2  tt0137523                Fight Club  1999     8.8  458173      139
# 3  tt0133093                The Matrix  1999     8.7  448114      136
# 4  tt1375666                 Inception  2010     8.9  385149      148
#
#                              genres
# 0                       Crime|Drama
# 1                    Crime|Thriller
# 2            Drama|Mystery|Thriller
# 3           Action|Adventure|Sci-Fi
# 4  Action|Adventure|Sci-Fi|Thriller

# %%
df['year'] = pd.to_datetime(df['year'], format="%Y")
df.head()
# Out:
#          ID1                     title       year  rating     ID2 duration  \
# 0  tt0111161  The Shawshank Redemption 1994-01-01     9.2  619479      142
# 1  tt0110912              Pulp Fiction 1994-01-01     9.0  490065      154
# 2  tt0137523                Fight Club 1999-01-01     8.8  458173      139
# 3  tt0133093                The Matrix 1999-01-01     8.7  448114      136
# 4  tt1375666                 Inception 2010-01-01     8.9  385149      148
#
#                              genres
# 0                       Crime|Drama
# 1                    Crime|Thriller
# 2            Drama|Mystery|Thriller
# 3           Action|Adventure|Sci-Fi
# 4  Action|Adventure|Sci-Fi|Thriller

# %%
df.drop(['ID1', 'ID2'], axis=1, inplace=True)
df.head()
# Out:
#                       title       year  rating duration  \
# 0  The Shawshank Redemption 1994-01-01     9.2      142
# 1              Pulp Fiction 1994-01-01     9.0      154
# 2                Fight Club 1999-01-01     8.8      139
# 3                The Matrix 1999-01-01     8.7      136
# 4                 Inception 2010-01-01     8.9      148
#
#                              genres
# 0                       Crime|Drama
# 1                    Crime|Thriller
# 2            Drama|Mystery|Thriller
# 3           Action|Adventure|Sci-Fi
# 4  Action|Adventure|Sci-Fi|Thriller

# %%
df = df.dropna()

# %%
genreset = set()

for x in df.genres:
    genreset.update(g for g in x.split('|'))
    
print genreset
# Out:
# set(['Sci-Fi', 'Crime', 'Romance', 'Animation', 'Music', 'Comedy', 'War', 'Horror', 'Film-Noir', 'Adult', 'News', 'Reality-TV', 'Thriller', 'Western', 'Mystery', 'Drama', 'Action', 'Musical', 'History', 'Family', 'Adventure', 'Fantasy', 'Sport', 'Biography'])

# %%
# for all the genres in the set, if the given movie contains the genre, return true for that genre
# a column is being created for each genre in genreset

for genre in genreset:
    df[genre] = [genre in movie.split('|') for movie in df.genres]
    
df.drop('genres', axis=1, inplace=True)
df.head()
# Out:
#                       title       year  rating duration Sci-Fi  Crime Romance  \
# 0  The Shawshank Redemption 1994-01-01     9.2      142  False   True   False
# 1              Pulp Fiction 1994-01-01     9.0      154  False   True   False
# 2                Fight Club 1999-01-01     8.8      139  False  False   False
# 3                The Matrix 1999-01-01     8.7      136   True  False   False
# 4                 Inception 2010-01-01     8.9      148   True  False   False
#
#   Animation  Music Comedy  ...   Mystery  Drama Action Musical History Family  \
# 0     False  False  False  ...     False   True  False   False   False  False
# 1     False  False  False  ...     False  False  False   False   False  False
# 2     False  False  False  ...      True   True  False   False   False  False
# 3     False  False  False  ...     False  False   True   False   False  False
# 4     False  False  False  ...     False  False   True   False   False  False
#
#   Adventure Fantasy  Sport Biography
# 0     False   False  False     False
# 1     False   False  False     False
# 2     False   False  False     False
# 3      True   False  False     False
# 4      True   False  False     False
#
# [5 rows x 28 columns]

# %%
df.duration = df.duration.apply(lambda y: int(y))
df.head()
# Out:
#                       title       year  rating  duration Sci-Fi  Crime  \
# 0  The Shawshank Redemption 1994-01-01     9.2       142  False   True
# 1              Pulp Fiction 1994-01-01     9.0       154  False   True
# 2                Fight Club 1999-01-01     8.8       139  False  False
# 3                The Matrix 1999-01-01     8.7       136   True  False
# 4                 Inception 2010-01-01     8.9       148   True  False
#
#   Romance Animation  Music Comedy  ...   Mystery  Drama Action Musical  \
# 0   False     False  False  False  ...     False   True  False   False
# 1   False     False  False  False  ...     False  False  False   False
# 2   False     False  False  False  ...      True   True  False   False
# 3   False     False  False  False  ...     False  False   True   False
# 4   False     False  False  False  ...     False  False   True   False
#
#   History Family Adventure Fantasy  Sport Biography
# 0   False  False     False   False  False     False
# 1   False  False     False   False  False     False
# 2   False  False     False   False  False     False
# 3   False  False      True   False  False     False
# 4   False  False      True   False  False     False
#
# [5 rows x 28 columns]

# %%
df.describe()
# Out:
#             rating     duration      Sci-Fi      Crime    Romance   Animation  \
# count  9999.000000  9999.000000        9999       9999       9999        9999
# mean      6.385989   103.580358  0.08970897  0.1867187  0.2441244  0.03140314
# std       1.189965    26.629310   0.2857787   0.389705  0.4295883   0.1744134
# min       1.500000     0.000000       False      False      False       False
# 25%       5.700000    93.000000           0          0          0           0
# 50%       6.600000   102.000000           0          0          0           0
# 75%       7.200000   115.000000           0          0          0           0
# max       9.200000   450.000000        True       True       True        True
#
#             Music     Comedy         War     Horror    ...        Mystery  \
# count        9999       9999        9999       9999    ...           9999
# mean   0.03710371  0.3922392  0.05120512  0.1215122    ...      0.1009101
# std     0.1890254   0.488274   0.2204269  0.3267379    ...      0.3012247
# min         False      False       False      False    ...          False
# 25%             0          0           0          0    ...              0
# 50%             0          0           0          0    ...              0
# 75%             0          1           0          0    ...              0
# max          True       True        True       True    ...           True
#
#            Drama     Action    Musical     History      Family  Adventure  \
# count       9999       9999       9999        9999        9999       9999
# mean    0.569757  0.1891189  0.0260026  0.03580358  0.07540754  0.1313131
# std    0.4951348  0.3916226  0.1591509   0.1858094    0.264061  0.3377594
# min        False      False      False       False       False      False
# 25%            0          0          0           0           0          0
# 50%            1          0          0           0           0          0
# 75%            1          0          0           0           0          0
# max         True       True       True        True        True       True
#
#           Fantasy       Sport   Biography
# count        9999        9999        9999
# mean   0.09160916  0.02880288  0.03940394
# std     0.2884879   0.1672605   0.1945638
# min         False       False       False
# 25%             0           0           0
# 50%             0           0           0
# 75%             0           0           0
# max          True        True        True
#
# [8 rows x 26 columns]

# %% [markdown]
# # Explore

# %%
df.plot()

# %% [markdown]
# # Summarize
