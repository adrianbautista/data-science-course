# %%
import pandas as pd
import numpy as np

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
customers_df = pd.read_csv('./data/customers.csv', header=None, index_col=0)
orders_df = pd.read_csv('./data/orders.csv', header=None, index_col=0)

# %%
customers_df.loc[customers_df[12] == 2][:5]
# Out:
#         1           2                    3   4        5   6      7   8   9   \
# 0
# 7   WVZTXZ  RMEVXCQGQF  9743191382 Dell Way NaN  SIIGBQF  NV  55961  US   1
# 8   LIWLAI  PVGRMMHSEQ  7576564107 Dell Way NaN  BKSRQJE  NJ  66444  US   1
# 10  FUOHXX  WMOEHWMMWM  2603867587 Dell Way NaN  HERSDPM  TN  75182  US   1
# 12  KGISQZ  IXDKAUUHCW  1896033667 Dell Way NaN  SBLZSFM  UT  18452  US   1
# 22  QIBTUS  RXITHVEPBC  5221450049 Dell Way NaN  EGDPBXY  AR  93269  US   1
#
#                      10          11  12                13       14      15  \
# 0
# 7   RMEVXCQGQF@dell.com  9743191382   2  5914961899630726  2011/02   user7
# 8   PVGRMMHSEQ@dell.com  7576564107   2  7663945967331529  2009/12   user8
# 10  WMOEHWMMWM@dell.com  2603867587   2  5486729339230806  2008/02  user10
# 12  IXDKAUUHCW@dell.com  1896033667   2  3715867913328111  2011/10  user12
# 22  RXITHVEPBC@dell.com  5221450049   2  6283100841101260  2008/08  user22
#
#           16  17      18 19
# 0
# ...

# %%
customers_df.groupby(customers_df[6]).count()[6]
# Out:
# 6
# AK    210
# AL    195
# AR    190
# AZ    177
# CA    186
# CO    217
# CT    226
# DC    205
# DE    196
# FL    193
# GA    201
# HI    201
# IA    209
# ID    197
# IL    180
# IN    182
# KS    192
# KY    212
# LA    203
# MA    214
# MD    187
# ME    169
# MI    189
# MN    176
# MO    196
# MS    183
# MT    228
# NC    161
# ND    186
# NE    191
# NH    195
# NJ    227
# NM    171
# NV    193
# NY    206
# OH    215
# OK    192
# OR    220
# PA    190
# RI    180
# SC    188
# SD    213
# TN    204
# TX    204
# UT    182
# VA    184
# VT    214
# WA    215
# WI    191
# WV    176
# WY    188
# Name: 6, Length: 51, dtype: int64

# %%
len(customers_df.ix[(customers_df[2].map(lambda x: x[:1] == 'Z'))])
# Out:
# 765

# %%
customers_df[[1]][1][1]
# Out:
# 'VKUUXF'

# %%
orders_df.head()
# Out:
#             1      2       3      4       5
# 0
# 1  2004-01-27   7888  313.24  25.84  339.08
# 2  2004-01-01   4858   54.90   4.53   59.43
# 3  2004-01-17  15399  160.10  13.21  173.31
# 4  2004-01-28  17019  106.67   8.80  115.47
# 5  2004-01-09  14771  256.00  21.12  277.12

# %%
customers_df.head()
# Out:
#        1           2                    3   4        5   6      7   8   9   \
# 0
# 1  VKUUXF  ITHOMQJNYX  4608499546 Dell Way NaN  QSDPAGD  SD  24101  US   1
# 2  HQNMZH  UNUKXHJVXB  5119315633 Dell Way NaN  YNCERXJ  AZ  11802  US   1
# 3  JTNRNB  LYYSHTQJRE  6297761196 Dell Way NaN  LWVIFXJ  OH  96082  US   1
# 4  XMFYXD  WQLQHUHLFE  9862764981 Dell Way NaN  HOKEXCD  MS  78442  US   1
# 5  PGDTDU  ETBYBNEGUT  2841895775 Dell Way NaN  RZQTCDN  AZ  16291  US   1
#
#                     10          11  12                13       14     15  \
# 0
# 1  ITHOMQJNYX@dell.com  4608499546   1  1979279217775911  2012/03  user1
# 2  UNUKXHJVXB@dell.com  5119315633   1  3144519586581737  2012/11  user2
# 3  LYYSHTQJRE@dell.com  6297761196   4  8728086929768325  2010/12  user3
# 4  WQLQHUHLFE@dell.com  9862764981   5  7160005148965866  2009/09  user4
# 5  ETBYBNEGUT@dell.com  2841895775   3  8377095518168063  2010/10  user5
#
#          16  17      18 19
# 0
# 1  password  55  100000  M
# ...

# %%
orders_df.groupby(orders_df[2]).count()[2]
# Out:
# 2
# 2     1
# 3     1
# 6     1
# 7     1
# 11    1
# 12    1
# 13    2
# 15    1
# 19    2
# 21    1
# 22    1
# 32    1
# 35    1
# 36    1
# 39    1
# ...
# 19971    1
# 19972    1
# 19974    1
# 19977    2
# 19978    1
# 19980    1
# 19981    1
# 19982    1
# 19986    1
# 19988    2
# 19989    1
# 19991    2
# 19993    1
# 19996    1
# 20000    1
# Name: 2, Length: 8996, dtype: int64

# %%
customer_orders = pd.merge(customers_df, orders_df, left_on=7, right_on=2, how='outer')

# %%
customer_orders[17].count()
# Out:
# 20161

# %%
customer_orders.groupby(customer_orders[17]).count()['1_y']
# Out:
# 17
# 18     4
# 19     3
# 20     7
# 21    12
# 22     6
# 23    11
# 24     5
# 25     4
# 26    13
# 27     7
# 28    12
# 29    16
# 30     8
# 31     8
# 32    13
# ...
# 76     5
# 77     4
# 78     8
# 79    11
# 80    10
# 81     8
# 82    10
# 83     5
# 84     6
# 85     7
# 86     5
# 87     8
# 88     9
# 89    12
# 90     3
# Name: 1_y, Length: 73, dtype: int64
